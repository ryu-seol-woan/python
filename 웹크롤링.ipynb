# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

url = "http://www.daum.net/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1

results = soup.findAll('a','link_favorsch')

search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n")
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# 2023년 05월 12일의 실시간 검색어 순위입니다.

# %%
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url = "https://search.daum.net/search?w=tot&q=%EB%8B%A4%EC%9D%8C%20%EC%8B%A4%EC%8B%9C%EA%B0%84%20%EA%B2%80%EC%83%89%EC%96%B4&nzq=%EC%8B%A4%EC%8B%9C%EA%B0%84%20%EA%B2%80%EC%83%89%EC%96%B4&DA=RSJ"
response = requests.get(url,headers = headers)
# print(response.text[:500])

soup = BeautifulSoup(response.text, 'html.parser',from_encoding='euc-kr')
# file = open('daum.html2', 'w')
# file.write(response.text)
# file.close()

# print(soup.title)
# print(soup.title.string)
# print(soup.findAll('meta'))

results = soup.findAll('ol', 'list_rank')

search_rank_file = open('rankresult.txt', 'a')

rank = 1
print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위"))

for result in results:
  search_rank_file.write( result.get_text())
  print(rank,'위:', result.get_text(), '\n')
  rank +=1
# Out:
# 2023년 05월 12일의 실시간 검색어 순위
# 1 위:    1 텐트 밖은 유럽 노르웨이 편     2 미스터 로또     3 꼬리에 꼬리를 무는 그날 이야기     4 팬텀싱어4     5 텐트 밖은 유럽
#
# 2 위:    6 나는 SOLO     7 나 혼자 산다     8 텐트 밖은 유럽 스페인 편     9 트랄랄라 브라더스     10 어서와 한국은 처음이지?
#
# 3 위:    1 범죄도시3     2 분노의 질주: 라이드 오어 다이     3 슬픔의 삼각형     4 아기공룡 둘리 : 얼음별 대모험 리마스터링     5 오펜하이머
#
# 4 위:    6 라이드 온     7 트랜스포머: 비스트의 서막     8 그 여름     9 귀공자     10 밀수
#
# 5 위:    1 문재인입니다     2 가디언즈 오브 갤럭시: Volume 3     3 존 윅 4     4 슈퍼 마리오 브라더스     5 스즈메의 문단속
#
# 6 위:    6 롱디     7 드림     8 엑소시스트: 더 바티칸     9 킬링 로맨스     10 스트리머
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:226: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
from datetime import datetime

# %%
# Out:
# [<ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">1</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EB%B2%94%EC%A3%84%EB%8F%84%EC%8B%9C3&amp;rtmaxcoll=1MV,EM1&amp;160244" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=1',event);">범죄도시3</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">2</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EB%B6%84%EB%85%B8%EC%9D%98%20%EC%A7%88%EC%A3%BC%3A%20%EB%9D%BC%EC%9D%B4%EB%93%9C%20%EC%98%A4%EC%96%B4%20%EB%8B%A4%EC%9D%B4&amp;rtmaxcoll=1MV,EM1&amp;167558" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=2',event);">분노의 질주: 라이드 오어 다이</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">3</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EC%8A%AC%ED%94%94%EC%9D%98%20%EC%82%BC%EA%B0%81%ED%98%95&amp;rtmaxcoll=1MV,EM1&amp;160409" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=3',event);">슬픔의 삼각형</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">4</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EC%95%84%EA%B8%B0%EA%B3%B5%EB%A3%A1%20%EB%91%98%EB%A6%AC%20%3A%20%EC%96%BC%EC%9D%8C%EB%B3%84%20%EB%8C%80%EB%AA%A8%ED%97%98%20%EB%A6%AC%EB%A7%88%EC%8A%A4%ED%84%B0%EB%A7%81&amp;rtmaxcoll=1MV,EM1&amp;121" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=4',event);">아기공룡 둘리 : 얼음별 대모험 리마스터링</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">5</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EB%9D%BC%EC%9D%B4%EB%93%9C%20%EC%98%A8&amp;rtmaxcoll=1MV,EM1&amp;165530" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=5',event);">라이드 온</a></span> </div> </li> </ol>, <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">6</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EC%98%A4%ED%8E%9C%ED%95%98%EC%9D%B4%EB%A8%B8&amp;rtmaxcoll=1MV,EM1&amp;158260" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=6',event);">오펜하이머</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">7</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EA%B7%B8%20%EC%97%AC%EB%A6%84&amp;rtmaxcoll=1MV,EM1&amp;169897" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=7',event);">그 여름</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">8</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%ED%8A%B8%EB%9E%9C%EC%8A%A4%ED%8F%AC%EB%A8%B8%3A%20%EB%B9%84%EC%8A%A4%ED%8A%B8%EC%9D%98%20%EC%84%9C%EB%A7%89&amp;rtmaxcoll=1MV,EM1&amp;165969" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=8',event);">트랜스포머: 비스트의 서막</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">9</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EA%B7%80%EA%B3%B5%EC%9E%90&amp;rtmaxcoll=1MV,EM1&amp;155850" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=9',event);">귀공자</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">10</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=1MV&amp;q=%EC%9D%B8%EB%94%94%EC%95%84%EB%82%98%20%EC%A1%B4%EC%8A%A4%3A%20%EC%9A%B4%EB%AA%85%EC%9D%98%20%EB%8B%A4%EC%9D%B4%EC%96%BC&amp;rtmaxcoll=1MV,EM1&amp;62731" onclick="smartLog(this,'dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=10',event);">인디아나 존스: 운명의 다이얼</a></span> </div> </li> </ol>, <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">1</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=DZR&amp;q=%EC%98%A4%EC%85%80%EB%A1%9C&amp;rtmaxcoll=DZR,TCS&amp ...

# %%
# Out:
# 1 위:    1 최경영의 최강시사     2 김현정의 뉴스쇼     3 임백천의 백뮤직     4 주현미의 러브레터     5 두시탈출 컬투쇼
#
# 2 위:    6 김종배의 시선집중     7 김혜영과 함께     8 김혜영과 함께     9 김영철의 파워FM     10 김현주의 행복한 동행
#
# 3 위:    1 오셀로     2 리어왕     3 라면     4 벚꽃동산     5 친정엄마와 2박3일
#
# 4 위:    6 늘근도둑 이야기     7 행복     8 파우스트     9 장수상회     10 테베랜드
#
# 5 위:    1 범죄도시3     2 분노의 질주: 라이드 오어 다이     3 슬픔의 삼각형     4 아기공룡 둘리 : 얼음별 대모험 리마스터링     5 라이드 온
#
# 6 위:    6 오펜하이머     7 그 여름     8 트랜스포머: 비스트의 서막     9 귀공자     10 인디아나 존스: 운명의 다이얼

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)

# %%
print(requests)
# Out:
# <module 'requests' from '/usr/local/lib/python3.10/dist-packages/requests/__init__.py'>

# %%
print(requests.get)
# Out:
# <function get at 0x7fc2c807d630>

# %%
# Out:
# <Response [200]>

# %%
url = 'https://www.daum.net'

# %%
response = requests.get(url)

# %%
print(response.text)
# Out:
# <!doctype html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8">
#   <title>Daum</title>
#   <meta http-equiv="x-ua-compatible" content="IE=edge">
#   <meta property="og:url" content="https://www.daum.net/">
#   <meta property="og:type" content="website">
#   <meta property="og:title" content="Daum">
#   <meta http-equiv="Pragma" content="no-cache">
#   <meta http-equiv="Expires" content="-1">
#   <meta name="referrer" content="origin">
#   <meta property="og:image" content="https://i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
#   <meta property="og:description" content="ì´ì©ì ì íê¶ì ê°íí ë´ì¤, ì¸ìì ëª¨ë  ì ë³´ë¥¼ ì°ê²°íë ê²ì. Daumìì ëì ê´ì¬ ì½íì¸ ë¥¼ ì¦ê²¨ë³´ì¸ì.">
#   <meta name="description" content="ì´ì©ì ì íê¶ì ê°íí ë´ì¤, ì¸ìì ëª¨ë  ì ë³´ë¥¼ ì°ê²°íë ê²ì. Daumìì ëì ê´ì¬ ì½íì¸ ë¥¼ ì¦ê²¨ë³´ì¸ì.">
#   <meta name="msapplication-task" content="name=Daum;action-uri=//www.daum.net/;icon-uri=/favicon.ico">
#   <meta name="msapplication-task" content="name=ë¯¸ëì´ë¤ì;action-uri=//news.daum.net/;icon-uri=/media_favicon.ico">
#   <meta name="msapplication-task" content="name=ë©ì¼;action-uri=//mail.daum.net;icon-uri=/mail_favicon.ico">
#   <link href="https://t1.daumcdn.net/top/favicon.ico" rel="shortcut icon">
#   <meta name="referrer" content="origin">
#   <link rel="search" type="application/opensearchdescription+xml" href="https://search.daum.net/OpenSearch.xml" title="ë¤ì">
#   <link rel="stylesheet" href="https://t1.daumcdn.net/top/tiller-pc/h/production/20230509_145946/common.css">
#  </head>
#  <body>
#   <script>
# window.tiller = { "serverTime": 1683855025499};
# window.tillerInitData={"header":{"timestamp":1683855025482},"body":{"variations":{},"tabs":{"media":{"code":"media","name":"ë¯¸ëì´","renderType":"NONE","position":1,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\"tab\":\"media\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"},"katv":{"code":"katv","name":"ì¹´ì¹´ì¤TV","renderType":"NONE","position":2,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\"tab\":\"katv\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"},"social":{"code":"social","name":"ìì","renderType":"NONE","position":3,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\"tab\":\"social\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"},"channel":{"code":"channel","name":"ì±ë","renderType":"NONE","position":4,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\"tab\":\"channel\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"},"pc_admin":{"code":"pc_admin","name":"PCì´ì","renderType":"NONE","position":0,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\"tab\":\"pc_admin\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"}},"boxes":{"media":[{"code":2372,"type":"PC_MEDIA_NEWS1","items":{"op":{"tab":"news1","title":"ë´ì¤","url":"https://news.daum.net/"},"issue":{"isSpecial":"false","iconType":"ISSUE2","title":"ì½ë¡ë 19 íí©","url":"https://news.daum.net/covid19","status":"off"},"breakingNewsOp":{"minCount":"3","status":"on"},"footLinkLeft":{"foot1":"{\"title\":\"í¬í \",\"url\":\"https://news.daum.net/photo/\",\"tiaraTag\":\"photo\"}","foot0":"{\"title\":\"ì°ì¬\",\"url\":\"https://news.daum.net/series/\",\"tiaraTag\":\"series\"}","foot3":"{\"title\":\"\",\"url\":\"\",\"tiaraTag\":\"\"}","footer":"{\"title\":\"ë´ì¤í\",\"url\":\"https://news.daum.net/\"}","foot2":"{\"title\":\"í©í¸ì²´í¬\",\"url\":\"https://focus.daum.net/ch/news/factcheck\",\"tiaraTag\":\"factcheck\"}","foot4":"{\"title\":\"\",\"url\":\"\",\"tiaraTag\":\"\"}","status":"on"},"footLinkRight":{"foot1":"{\"title\":\"íì¨\",\"url\":\"https://search.daum.net/search?w=tot&q=íì¨&DA=TMZ\",\"tiaraTag\":\"exchange\"}","foot0":"{\"title\":\"ì½ì¤í¼\",\"url\":\"https://search.daum.net/search?w=tot&q=ì¦ì&DA=TMZ\",\"tiaraTag\":\"stock\"}","foot3":"{\"title\":\"TVí¸ì±\",\"url\":\"https://search.daum.net/search?w=tot&q=í¸ì±í&DA=TMZ\",\"tiaraTag\":\"tv\"}","foot2":"{\"title\":\"ì¤ëìì´ì¸\",\"url\":\"https://search.daum.net/search?w=tot&q=ì´ì¸&DA=TMZ\",\"tiaraTag\":\"fortune\"}","status":"on"},"specialLink":{"displayType":"specialLink","iconType":"LIVE","title":"ì¤ëì KBOë¦¬ê·¸","url":"https://sports.daum.net/schedule/kbo","status":"off"}},"feeds":{"pc_media_breaking_news":"[{\"id\":\"hamny-20230512102016350\",\"title\":\"ì ë¶\\\"ëë§ì IAEAíìêµ­ ìë... æ¥, íì§ë°©ë¬¸ íì©ì íêµ­ë¿\\\"\",\"url\":\"https://v.daum.net/v/20230512102016350\",\"clusters\":[{\"clusterId\":5150092,\"clusterTitle\":\"ì ì¹\",\"clusterOperationGroup\":\"NEWS\",\"clusterTypeId\":55,\"clusterStatus\":\"SERVICE\",\"clusterKeywordType\":\"NONE\",\"clusterLevel\":0,\"clusterServiceType\":\"SERVICE\",\"clusterTypeName\":\"ë¶ì¼ë³ë´ì¤\"},{\"clusterId\":5122367,\"clusterTitle\":\"[ì¹ì¸] ìë³´ ê¸°ì¬\",\"clusterOperationGroup\":\"NEWS\",\"clusterTypeId\":42,\"clusterStatus\":\"SERVICE\",\"clusterKeywordType\":\"NONE\",\"clusterLevel\":0,\"clusterServiceType\":\"MANAGEMENT\",\"clusterTypeName\":\"íì§\"},{\"clusterId\":5650267,\"clusterTitle\":\"[ì íµì ì¸] ê´ì¬ì¬í­\",\"clusterOperationGroup\":\"INTEREST\",\"clusterTypeId\":42,\"clusterStatus\":\"SERVICE\",\"clusterKeywordType\":\"NONE\",\"clusterLevel\":0,\"clusterServiceType\":\"MANAGEMENT\",\"clusterTypeName\":\"íì§\"},{\"clusterId\":5726103,\"clusterTitle\":\"[ì íµì ì¸] ì´ìí¤ìë\",\"clusterOperationGroup\":\"INTEREST\",\"clusterTypeId\":42,\"clusterStatus\":\"SERVICE\",\"clusterKeywordType\":\"NONE\",\"clusterLevel\":0,\"clusterServiceType\":\"MAN ...
# </script>
#   <noscript>
#    ì´ ì¬ì´í¸ì ê¸°ë¥ì ëª¨ë íì©íê¸° ìí´ìë ìë°ì¤í¬ë¦½í¸ë¥¼ íì±í ìí¬ íìê° ììµëë¤. <a href="https://www.enable-javascript.com/ko/"> ë¸ë¼ì°ì ìì ìë°ì¤í¬ë¦½í¸ë¥¼ íì±ííë ë°©ë²</a>ì ì°¸ê³  íì¸ì.
#   </noscript>
#   <script src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>
#   <script src="https://t1.daumcdn.net/top/tiller-pc/lib/1667278587486/polyfill.min.js"></script>
#   <script src="https://t1.daumcdn.net/top/tiller-pc/h/production/20230509_145946/index.js" crossorigin></script>
#   <script src="https://t1.daumcdn.net/kas/static/ba.min.js" defer></script>
#   <script src="https://t1.daumcdn.net/top/tiller-pc/1671698827061/tiller-pc-suggest.js" type="text/javascript" defer></script>
#  </body>
# </html>

# %%
print(response.url)
# Out:
# https://www.daum.net/

# %%
print(response.content)
# Out:
# b'<!doctype html>\n<html lang="ko">\n <head>\n  <meta charset="utf-8">\n  <title>Daum</title>\n  <meta http-equiv="x-ua-compatible" content="IE=edge">\n  <meta property="og:url" content="https://www.daum.net/">\n  <meta property="og:type" content="website">\n  <meta property="og:title" content="Daum">\n  <meta http-equiv="Pragma" content="no-cache">\n  <meta http-equiv="Expires" content="-1">\n  <meta name="referrer" content="origin">\n  <meta property="og:image" content="https://i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">\n  <meta property="og:description" content="\xec\x9d\xb4\xec\x9a\xa9\xec\x9e\x90 \xec\x84\xa0\xed\x83\x9d\xea\xb6\x8c\xec\x9d\x84 \xea\xb0\x95\xed\x99\x94\xed\x95\x9c \xeb\x89\xb4\xec\x8a\xa4, \xec\x84\xb8\xec\x83\x81\xec\x9d\x98 \xeb\xaa\xa8\xeb\x93\xa0 \xec\xa0\x95\xeb\xb3\xb4\xeb\xa5\xbc \xec\x97\xb0\xea\xb2\xb0\xed\x95\x98\xeb\x8a\x94 \xea\xb2\x80\xec\x83\x89. Daum\xec\x97\x90\xec\x84\x9c \xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xec\xa6\x90\xea\xb2\xa8\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94.">\n  <meta name="description" content="\xec\x9d\xb4\xec\x9a\xa9\xec\x9e\x90 \xec\x84\xa0\xed\x83\x9d\xea\xb6\x8c\xec\x9d\x84 \xea\xb0\x95\xed\x99\x94\xed\x95\x9c \xeb\x89\xb4\xec\x8a\xa4, \xec\x84\xb8\xec\x83\x81\xec\x9d\x98 \xeb\xaa\xa8\xeb\x93\xa0 \xec\xa0\x95\xeb\xb3\xb4\xeb\xa5\xbc \xec\x97\xb0\xea\xb2\xb0\xed\x95\x98\xeb\x8a\x94 \xea\xb2\x80\xec\x83\x89. Daum\xec\x97\x90\xec\x84\x9c \xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xec\xa6\x90\xea\xb2\xa8\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94.">\n  <meta name="msapplication-task" content="name=Daum;action-uri=//www.daum.net/;icon-uri=/favicon.ico">\n  <meta name="msapplication-task" content="name=\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4\xeb\x8b\xa4\xec\x9d\x8c;action-uri=//news.daum.net/;icon-uri=/media_favicon.ico">\n  <meta name="msapplication-task" content="name=\xeb\xa9\x94\xec\x9d\xbc;action-uri=//mail.daum.net;icon-uri=/mail_favicon.ico">\n  <link href="https://t1.daumcdn.net/top/favicon.ico" rel="shortcut icon">\n  <meta name="referrer" content="origin">\n  <link rel="search" type="application/opensearchdescription+xml" href="https://search.daum.net/OpenSearch.xml" title="\xeb\x8b\xa4\xec\x9d\x8c">\n  <link rel="stylesheet" href="https://t1.daumcdn.net/top/tiller-pc/h/production/20230509_145946/common.css">\n </head>\n <body>\n  <script>\nwindow.tiller = { "serverTime": 1683855025499};\nwindow.tillerInitData={"header":{"timestamp":1683855025482},"body":{"variations":{},"tabs":{"media":{"code":"media","name":"\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4","renderType":"NONE","position":1,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\\"tab\\":\\"media\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"katv":{"code":"katv","name":"\xec\xb9\xb4\xec\xb9\xb4\xec\x98\xa4TV","renderType":"NONE","position":2,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\\"tab\\":\\"katv\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"social":{"code":"social","name":"\xec\x86\x8c\xec\x85\x9c","renderType":"NONE","position":3,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\\"tab\\":\\"social\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"channel":{"code":"channel","name":"\xec\xb1\x84\xeb\x84\x90","renderType":"NONE","position":4,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\\"tab\\":\\"channel\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"pc_admin":{"code":"pc_admin","name":"PC\xec\x9a\xb4\xec\x98\x81","renderType":"NONE","position":0,"criteriaTabCode":null,"board":false,"morePage":false,"page":"{\\"tab\\":\\"pc_admin\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"}},"boxes":{"media":[{"code":2372,"type":"PC_MEDIA_NEWS1","items":{"op":{"tab":"news1","title":"\xeb\x89\xb4\xec\x8a\xa4","url":"https://news.daum.net/"} ...

# %%
print(response.encoding)
# Out:
# ISO-8859-1

# %%
print(response.headers)
# Out:
# {'Date': 'Fri, 12 May 2023 01:30:25 GMT', 'Content-Type': 'text/html', 'Content-Length': '114136', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Access-Control-Allow-Origin': '*', 'Accept-Ranges': 'bytes', 'X-WCSS': 'dC1jb21tb24wMS1id2NhY2hlNDc6bWlzczoxNTQ=', 'Report-To': '{"group":"kakao-nel","max_age":86400,"endpoints":[{"url":"https://nel.onkakao.net/upload/"}],"include_subdomains":true}', 'NEL': '{"report_to":"kakao-nel","max_age":86400,"include_subdomains":true}', 'Cache-Control': 'no-cache, no-store', 'Pragma': 'no-cache', 'content-encoding': 'gzip', 'Strict-Transport-Security': 'max-age=15724800'}

# %%
print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(response.links)
# Out:
# {}

# %%
print(response.ok)
# Out:
# True

# %%
print(response.status_code)
# Out:
# 200

# %%
pip install beautifulsoup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting beautifulsoup
#   Downloading BeautifulSoup-3.2.2.tar.gz (32 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.daum.net/"
response = requests.get(url)
# print(response.text)

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d312cf1ac4df> in <cell line: 1>()
# ----> 1 print(response.txt)
#
# AttributeError: 'Response' object has no attribute 'txt'
