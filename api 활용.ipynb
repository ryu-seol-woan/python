# %%
import requests
import json

city = "Seoul"
apikey = "af9059b74320e48c08e137d4d42786b9"
lang = "kr"
api = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}&units=metric&lang={lang}"

result = requests.get(api)
data = json.loads(result.text)

print(data["name"],"의 날씨입니다.")
print("날씨는 ",data["weather"][0]["description"],"입니다.")
print("현재 온도는 ",data["main"]["temp"],"입니다.")
print("하지만 체감 온도는 ",data["main"]["feels_like"],"입니다.")
print("최저 기온은 ",data["main"]["temp_min"],"입니다.")
print("최고 기온은 ",data["main"]["temp_max"],"입니다.")
print("습도는 ",data["main"]["humidity"],"입니다.")
print("기압은 ",data["main"]["pressure"],"입니다.")
print("풍향은 ",data["wind"]["deg"],"입니다.")
print("풍속은 ",data["wind"]["speed"],"입니다.")
# Out:
# Seoul 의 날씨입니다.
# 날씨는  맑음 입니다.
# 현재 온도는  23.56 입니다.
# 하지만 체감 온도는  22.7 입니다.
# 최저 기온은  19.69 입니다.
# 최고 기온은  25.66 입니다.
# 습도는  28 입니다.
# 기압은  1016 입니다.
# 풍향은  290 입니다.
# 풍속은  4.12 입니다.

# %%
city = 'Busan'
apikey = "af9059b74320e48c08e137d4d42786b9"
lang = 'kr'
units ='metric'
api = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={apikey}&lang={lang}&units={units}"

print(api)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=Busan&appid=af9059b74320e48c08e137d4d42786b9&lang=kr&units=metric

# %%
import requests
import json

# %%
print(data,'\n')
# Out:
# {'coord': {'lon': 126.9778, 'lat': 37.5683}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 296.71, 'feels_like': 295.85, 'temp_min': 292.84, 'temp_max': 298.81, 'pressure': 1016, 'humidity': 28}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 290}, 'clouds': {'all': 0}, 'dt': 1683873406, 'sys': {'type': 1, 'id': 8105, 'country': 'KR', 'sunrise': 1683836769, 'sunset': 1683887451}, 'timezone': 32400, 'id': 1835848, 'name': 'Seoul', 'cod': 200}

# %%
result = requests.get(api)
data = json.loads(result.text)

# %%
최고기온 = data['main']['temp_max']
습도 = data['main']['humidity']
기압 = data['main']['pressure']
풍향 = data['wind']['deg']
풍속 = data['wind']['speed']

# %%
print(f'최고기온은 {최고기온}이며 습도는 {습도}이며 기압은 {기압}이며 풍향은{풍향}이며 풍속은 {풍속}이다 ')
# Out:
# 최고기온은 20.99이며 습도는 52이며 기압은 1016이며 풍향은210이며 풍속은 6.17이다

# %%
print('최저기온은', data['main']['temp_min'], '입니다')
print(data['name'],"의 날씨는 " ,data['weather'][0]['description'],"이며 온도는 ", data['main']['temp'])
# Out:
# 최저기온은 19.69 입니다
# Seoul 의 날씨는  맑음 이며 온도는  23.56

# %%
# Out:
# 최저기온은 292.84 입니다
# Seoul 의 날씨는  clear sky 이며 온도는  296.71

# %%
# print(type(result.text))
# Out:
# <class 'str'>

# %%
# print(type(data))
# Out:
# <class 'dict'>

# %%
for re in result:
  print(re)
# Out:
# b'{"coord":{"lon":126.9778,"lat":37.5683},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"sta'
# b'tions","main":{"temp":296.56,"feels_like":295.61,"temp_min":292.84,"temp_max":298.81,"pressure":1016,"humidity":25},"visibility"'
# b':10000,"wind":{"speed":4.12,"deg":290},"clouds":{"all":0},"dt":1683872113,"sys":{"type":1,"id":8105,"country":"KR","sunrise":168'
# b'3836769,"sunset":1683887451},"timezone":32400,"id":1835848,"name":"Seoul","cod":200}'
