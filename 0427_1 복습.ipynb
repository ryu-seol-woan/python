# %%
def hello():
  return


n = hello # function
o = print # built in function
p = lambda

# %%
def hello():
    return

class A:
    pass

a = 10     #int, 정수형
b = 10.1   #float, 실수
c = -1
d = True   #bool, 논리형(부울형, 참거짓형)
e = 'good'
f = '10'   #str, 문자열
g = 'kim'
h = 'honggildong'
i = 'example'
j = 10 + 2j #complex, 복소수
k = 0b110   #int, 2진법 
l = 0o56    #int, 8진법
m = 0xAC    #int, 16진법

##########
n = hello # function
o = print # bulit-in function
p = lambda x:x**2 # function
q = A # class
r = A() # instance
##########

print('type(10) : ', type(a))
print('type(10.1) : ', type(b))
print('type(-1) : ', type(c))
print('type(True) : ', type(d))
print('type(\'good\') : ', type(e))
print('\'10\' + \'10\' : ', f + f)
print('\'10\' * 3', f * 3)
print('\'hong\' + \'gildong\'', g + h)
print('type(\'gildong\') : ', type(h))
print('type(\'gildong100!!\') : ', type(i))
print('type(10 + 2j) : ', type(j))
print('type(0b110) : ', type(k))
print(k)
print('type(0o56) : ', type(i))
print(i)
print('type(0xAC) : ', type(m))
print(m)
# Out:
# type(10) :  <class 'int'>
# type(10.1) :  <class 'float'>
# type(-1) :  <class 'int'>
# type(True) :  <class 'bool'>
# type('good') :  <class 'str'>
# '10' + '10' :  1010
# '10' * 3 101010
# 'hong' + 'gildong' kimhonggildong
# type('gildong') :  <class 'str'>
# type('gildong100!!') :  <class 'str'>
# type(10 + 2j) :  <class 'complex'>
# type(0b110) :  <class 'int'>
# 6
# type(0o56) :  <class 'str'>
# example
# type(0xAC) :  <class 'int'>
# 172

# %% [markdown]
# # 변수의 속성

# %% [markdown]
# * 영문과 숫자를 사용할 수 있지만, 숫자로 시작하지는 못합니다.
# * 특수문자는 사용하지 않아요.(언더바(_)는 사용합니다. 스네이크 표기법, 특수문자나 이미중 사용 가능한 것들이 있기는 합니다. 권하지 않습니다.)
# * 예약어는 사용하지 않습니다.(if, elif, while, for, etc)
# * 대소문자는 구분합니다.
# * 언더바로만 사용하거나 언더바로 시작할 수 있습니다.
# * 대문자로 시작하는 변수를 사용할 수 있지만, 관습적으로 대문자로 시작하는 변수는 Class로 만들기 때문에 소문자로 시작하는 변수를 만들기를 권합니다. Class는 보통 파스칼 표기법을 따릅니다. 다만 회사 컨벤션마다 다릅니다.

# %% [markdown]
# # 입력과 출력

# %%
x = input()
print(x + x)
# Out:
# 5
# 55

# %%
type(print)
# https://docs.python.org/3/library/functions.html
# Out:
# builtin_function_or_method

# %%
leehojun = print
leehojun('hello world')
id(print) ,id(leehojun)
# Out:
# hello world
# (140234436155088, 140234436155088)

# %%
print("hellow world", end = '!')
# Out:
# hellow world!

# %%
이름 = '이호준'
나이 = 10
print('1. 제이름은', 이름, '입니다. 제나이는', 나이,'입니다')
print(f'2. 제이름은 {이름} 입니다. 제나이는 {나이} 입니다')
print('3. 제이름은 {} 입니다. 제나이는 {} 입니다'.format(이름,나이))
# Out:
# 1. 제이름은 이호준 입니다. 제나이는 10 입니다
# 2. 제이름은 이호준 입니다. 제나이는 10 입니다
# 3. 제이름은 이호준 입니다. 제나이는 10 입니다

# %%
# format 용법이 생겼습니다.
# format 용법만 별도 정리 해드리겠습니다. (1시간 정도)
name = 'hojun'
age = 11
height = 175.8888
txt = 'name {} age {}'
print('name {} age {} height {:.2f}'.format(name, age,height))
print('name {0} age {1}'.format(name, age))
print('name {1} age {1}'.format(name, age))
print(txt.format(name, age))
# Out:
# name hojun age 11 height 175.89
# name hojun age 11
# name 11 age 11
# name hojun age 11

# %%
# f-string 용법이 생겼습니다.(3.6 version에서 새로 나옴)
name = 'hojun'
age = 11
print(f'name: {name} age: {age}')
# Out:
# name: hojun age: 11

# %% [markdown]
# # str(문자열)
#
# *왜 문자형이 아니라 문자열일까요요

# %%
a = 'Hello World'
type(a)
# Out:
# str

# %%
b = 'paullab CEO leehojun'

b[0], b[1]
# Out:
# ('p', 'a')

# %%
a.lower()
# Out:
# 'hello world'

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
a.islower() #전부 소문자인가가
# Out:
# False

# %%
a.isupper() #전부 대문자인가가
# Out:
# False

# %%
'123'.isdigit() # 숫자인가
# Out:
# True

# %%
'123'.isalpha() #알파벳인가
# Out:
# False

# %%
#아래 문자열 중 숫자만 더해라
s=0
for i in '123jlasfdj4q2350fdsa':
  if i.isdigit():
    s += int(i)
s
# Out:
# 20

# %%
'hellow world'.count('l')
# Out:
# 3

# %%
#1부터 100까지 8의 갯수 모두 세기

str(list(range(101))).count('8')
# Out:
# 20

# %%
'leehojun'.center(20, '!')
# Out:
# '!!!!!!leehojun!!!!!!'

# %%
'leehojun'.center(10)
# Out:
# ' leehojun '

# %%
'paullab CEO leehojun'.rjust(30) #오른쪽 정렬
# 'paullab CEO leehojun'.ljust(30) #왼쪽 정렬
# 'paullab CEO leehojun'.center(30)#가운데 정렬
# Out:
# '          paullab CEO leehojun'

# %%
'leehojun'.index('h')
#못찾으면 error
# Out:
# 3

# %%
'leehojun'.find('h')
#못찾으면 -1
# Out:
# 3

# %%
'paullab CEO leehojun.'.endswith('.') # 마침표로 끝났느냐?
# Out:
# True

# %%
'paullab CEO leehojun.'.endswith('!') # 느낌표로 끝났느냐?
# Out:
# False

# %%
''.join(['hello', 'world','hojun'])
'!'.join(['hello', 'world','hojun'])
'-'.join(['hello', 'world','hojun'])
#join 하려면 string형이어야함
# Out:
# 'hello-world-hojun'

# %%
# format 용법이 생겼습니다.
# format 용법만 별도 정리 해드리겠습니다. (1시간 정도)
name = 'hojun'
age = 11
txt = 'name {} age {}'
print('name {} age {}'.format(name, age))
print('name {0} age {1}'.format(name, age))
print('name {1} age {1}'.format(name, age))
print(txt.format(name, age))
# Out:
# name hojun age 11
# name hojun age 11
# name 11 age 11
# name hojun age 11

# %%
'hello world'.find('l')
'hello world'.rfind('l')
'hello world'.rindex('l')
# Out:
# 9

# %%
'        hello world         '.strip() #rstrip, lstrip
# Out:
# 'hello world'

# %%
'100'.zfill(10) # 10자리를 채웁니다.
# Out:
# '0000000100'

# %%
'010-0000-0000'.split('-')
'010-00!00-00!00'.split('!')
# Out:
# ['010-00', '00-00', '00']

# %%
'paullab CEO leehojun'.replace('CEO', 'CTO') #STR이 나와야 STR 매서드 체이닝 가능
# Out:
# 'paullab CTO leehojun'

# %%
'paullab CEO leehojun'.replace('CEO', 'CTO').split(' ')
# Out:
# ['paullab', 'CTO', 'leehojun']

# %%
암호 = '''  + +-+ -+-  
  ++ -- +-+  
  ++-+ -+ -  
  + ++-+ -+  '''

print(암호)
암호.split('\n')[0]
# Out:
#   + +-+ -+-
#   ++ -- +-+
#   ++-+ -+ -
#   + ++-+ -+
# '  + +-+ -+-  '

# %%
for i in  range(4):
  이진수i = 암호.split('\n')[i].strip().replace(' ','').replace('+','1').replace('-','0')
  print(chr(int(이진수i,2)))
# Out:
# j
# e
# j
# u

# %%
# 지금 이 코드에서는 strip을 할 이유가 없지만 앞 뒤 공백만 제거해야 할 때가 있습니다.

이진수 = 암호.split('\n')[0].strip().replace(' ', '').replace('+', '1').replace('-', '0')
int(이진수, 2)
# Out:
# 106

# %%
chr(106) # 유니코드표에서 숫자로 문자 출력
ord('j') # 유니코드표에서 문자를 숫자로 출력
# Out:
# 106

# %%
# '010-0000-0000'.split('-').zfill(10) # error 앞에서 진행한 split이 list를 반환하기 때문에 zfill을 사용할 수 없습니다.
'010-0000-0000'.split('-').count('0000') # 이건 가능합니다. count는 str에도 있지만 list에도 있어요.
# Out:
# 2

# %%
# 아래 3개는 모두 string 입니다.

a = 10

'hello world {}'.format(a)
f'hello world {a}'
r'hello world'
# Out:
# 'hello world'

# %%
print(r'hello \n world') #r : raw 날것의
# Out:
# hello \n world

# %%
''.join(['1','2','3','4'])
# Out:
# '1234'

# %%
규칙테이블 = str.maketrans('le','12')
'paullab CEO leehogun'.translate(규칙테이블) #어떤 규칙을 정하는것
# Out:
# 'pau11ab CEO 122hogun'

# %% [markdown]
# # 문자열의 활용

# %%
name = 'Guido van Rossum'
print(name[0])
print(name[1])
print(name[2])
# Out:
# G
# u
# i

# %%
s = '위니브 월드 외각에 살고 있는 생선가게...'
# s[start:stop:step]
s[0:6]
s[:6]
s[4:6]
s[7:9]
s[s.find('외각'):s.find('외각')+2]
s[-1]
s[:-5]
s[:-1] # 많이 사용합니다.
s[-7:-1] # 많이 안씁니다.
s[::2]
s[::-1]
# Out:
# '...게가선생 는있 고살 에각외 드월 브니위'

# %%
s[0:4]
# Out:
# '위니브 '

# %%
s = 'leehojun'

s + s
s * 3
# s/s  # error 
# s//s # error 
# s-s  # error
# Out:
# 'leehojunleehojunleehojun'

# %% [markdown]
# # 형 변환

# %%
print(type(int(3.5)))
print(int(3.5))
print(type(float(3)))
print(float(3))
print(type(str(3)))
print(str(3))
# Out:
# <class 'int'>
# 3
# <class 'float'>
# 3.0
# <class 'str'>
# 3

# %%
# [10, 20, 15, 17, '철수'] # 감기가 걸려스
l = [10, 20, 15, 17, None]
len(l)
# Out:
# 5

# %% [markdown]
# # 불린

# %%
# 숫자 : 0외에 다른 숫자는 다 참
# 문자 : ''외에 다른 문자는 다 참
# 리스트 : []외에 다른 리스트는 다 참
# None : False
print("bool('test') : ", bool('test'))
print("bool(1) : ", bool(1))
print("bool(0) : ", bool(0))
print("bool(-1) : ", bool(-1))
print("bool(' ') : ", bool(' '))
print("bool('') : ", bool(''))
print("bool(None) : ", bool(None))
# Out:
# bool('test') :  True
# bool(1) :  True
# bool(0) :  False
# bool(-1) :  True
# bool(' ') :  True
# bool('') :  False
# bool(None) :  False

# %% [markdown]
# # 산술 연산자자

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a / b) # float
print(a // b) # int
print(a * b)
print(a ** b)
print(a % b) # 나머지
# Out:
# 13
# 7
# 3.3333333333333335
# 3
# 30
# 1000
# 1

# %% [markdown]
# # 비교 연산자

# %%
a = 10
b = 3

print(a == b) # 같은가?
print(a != b) # 다른가?
print(a > b)
print(a >= b)
print(a < b)
print(a <= b)
# Out:
# False
# True
# True
# True
# False
# False

# %% [markdown]
# # 논리 연산자

# %%
# True : 1
# False : 0
# and : 논리곱
# or : 논리합
# not : 부정

# %%
# True and False
# 둘 중 하나라도 False라면 False
# and는 위와 같은 속성 때문에 
# 둘 다 만족해야하는 '조건'에 사용합니다.

for i in range(101):
    if i % 3 == 0 and i % 5 == 0:
        print(i)

# for i in range(101):
#     if i % 3 == 0:
#         if i % 5 == 0:
#             print(i)

# %%
10 and 20
# Out:
# 20

# %%
0 and 20
# Out:
# 0

# %%
10 or 20
# Out:
# 10

# %%
0 or 20
# Out:
# 20

# %% [markdown]
# # 비트 연산산

# %%
7 & 5

# 111
# 101
#----
# 101
# Out:
# 5

# %%
7 | 5

# 111
# 101
#----
# 101
# Out:
# 7

# %%
# 8bit

# 00000000
# 11111111

# 256개
# 0 ~ 255까지 사용? 음수사용 불가!
# 그래서 부호비트를 사용하는데
# ~는 비트단위로 전환을 하는 것입니다.

# 00001010 (10) -> not을 취하게 되면
# 11110110 (-10)-> 위와 숫자를 더하게 되면
# 00000000

~-10
# Out:
# 9

# %% [markdown]
# # 할당 연산산

# %%
a = 10
a = a+ 10
a
# Out:
# 20

# %%
a = 10
a += 10
a
# Out:
# 20

# %% [markdown]
# # 식별 연산산
#
# * 메모리 할당 값 비교교

# %%
a = 10
b = 10
print(id(a), id(b))

a is b
# Out:
# 140234436364880 140234436364880
# True

# %%
a = 999
b = 999
print(id(a), id(b))

a is b
# Out:
# 140233170053744 140233170054256
# False

# %%
a = [1, 2, 3]
b = [1, 2, 3]

print(id(a), id(b))

a is b, a is not b
# Out:
# 140233169862976 140233170997760
# (False, True)

# %%
a == b # 메모리 주소가 아니라 값만 비교하게 됩니다.
# Out:
# True

# %% [markdown]
# # 멤버 연산산

# %%
10 in [1,2,3]
# Out:
# False

# %%
10 in [1,2,3,10]
# Out:
# True

# %%
'one' in { 'one':10, 'two': 20}
# Out:
# True

# %%
20 in {'one' : 10, 'two': 20}
# Out:
# False

# %%
'l' in 'hello'
# Out:
# True

# %%
a = {'key':'value', 'key2':'value'}
'key' in a
# Out:
# True

# %%
d = {'one':10, 'two':20, 'three' : 30}

# %%
d.values()
# Out:
# dict_values([10, 20, 30])

# %%
print(max(d.values()))
print(max(d,key=d.get))
# Out:
# 30
# three

# %%
# 10000원을 들고 가서 1200원짜리 아이스크림 먹었을 때 잔돈의 갯수가 가장 적은 경우를 구하라
잔돈 = 8800

오천원갯수 = 잔돈 // 5000
잔돈 = 잔돈 - 오천원갯수 * 5000

천원의갯수 = 잔돈 // 1000
잔돈 = 잔돈 - 천원의갯수 * 1000

오백원갯수 = 잔돈 // 500
잔돈 = 잔돈 - 오백원갯수 * 500

백원갯수 = 잔돈 // 100
잔돈 = 잔돈 - 백원갯수 * 100

print(f'오천원은 {오천원갯수}개, \
천원은 {천원의갯수}개, \
오백원은 {오백원갯수}개, \
백원 {백원갯수}개를 거슬러 드립니다.')
# Out:
# 오천원은 1개, 천원은 3개, 오백원은 1개, 백원 3개를 거슬러 드립니다.
