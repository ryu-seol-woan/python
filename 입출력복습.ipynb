# %% [markdown]
# # 파이썬 스타일 코드 가이드라인인
#
# * 1. 들여쓰기는 공백 문자 네 개로 하자.
# * 2. 한줄의 최대 글자는 79자로 한다.
# * 3. 최상위 함수와 클래스 정의들은 두 줄씩 띄우자.
# * 4. 파일은 UTF-8 또는 아스키(ASCII)로 인코딩하자.
# * 5. 한 import 문에선 모듈 하나만 불러온다.
# * 6. 소괄호나 중괄호, 대괄호 사이에 추가로 공백을 주지 말고, 쉼표 안에도 공백을 주지 말자,
# * 7. 클래스 이름은 카멜케이스(CamelCase)를 따르자.
# * 8. 예외명은 Error로 끝내자.
# * 9. 함수 이름은 separated_by_underscores처럼 소문자와 밑줄 문자(_)를 이용해서 짓자.
# * 10. 비공개인 속성이나 메서드 이름은 밑줄 문자로 시작하자(_private).

# %% [markdown]
# ##1.1 블럭 주석
#
# * 바로 뒤에 오는 코드를 설명하고
# * 주석 내용이 다루는 코드와 동일한 들여쓰기 레벨에서 표기한다.
# * 한개의 #을 달고 주석을 기록한다.

# %%
# 예제 1.1
# 유저의 이름을 입력받고, 문자형이 아닌것을 주의하세요.

user_input = input("유저 이름을 입력하세요")
normalized_data = normalizednormalize_data(user_inputs)

# %% [markdown]
# ##1.2 인라인 주석
#
# * 코드와 같은 줄에 기록
# * #을 붙인 후 내용 기록
# * 코드와 적어도 두칸 이상 분리한다.

# %%
# ex1.1.2

연봉_인센포함 = 초기연봉 * 1.02   # 초기연봉에 2% 상승된 것이 인센포함된 연봉(23.05.01) 변경시 수정 바람

# %% [markdown]
# ##1.3 문서 형태 주석
#
# * 모듈, 클래스, 함수, 메소드 등 정보를 제공하는 용도 docstring이라고 함
# * 다른 주석과 달리 쌍따옴표나 따움표 3개로 구성
# * 함수 바로 밑에 내용을 적는다.
# * 여러줄로도 적을수 있다.

# %%
#1.1.3 문서 주석 - 한줄 형태

def quicksort():
""" Quicksort를 사용하여 보다 빠르게 정렬하는 함수 """

#1.1.3 문서 주석 - 두줄 이상 형태

def salary_increase(salary, percentage, rating):
    """ 성과에 의한 연봉 변화 함수
    1 - 2등급 - 연봉 10% 상승
    3 - 4등급 - 연봉 5%  상승
    5 - 6등급 - 연봉 동결
    7 - 10등급 - 연봉 5% 삭감

# %% [markdown]
# #2. 레이아웃
#
# [임포트]
# * import는 가장 위에 기록 한다.
# * 한줄에 하나씩 쓰는것을 추천한다.
#
# [들여쓰기]
# * 들여쓰기는 4칸씩 띄어쓰기를 꼭 지킨다. - Tab을 활용해도 되지만 통일 필요 (수업때는 Tab)
# * 함수의 줄 바꿈시에는 구분이 가능하도록 한다.
#
# [탭과 스페이스]
# * 탭보다는 스페이스를 사용하도록 노력하고, 섞어서 쓰지 말자
#
# [글자 길이 / 줄 바꿈]
# * 주석은 72자정도 / 최대 글자수는 79자 정도로 제한하는 것이 좋음
#
# [빈줄 넣기]
# * 일반적으로 클래스나 함수는 두줄로 분리해서 구분하기 좋게 한다.
# * 그러나 클래스나 함수 안에 함수는 논리적으로 구분이 되는 부분에서 한줄을 띄워도 좋다.
#
# [연산하는 경우]
# * 연산을 많이 할 경우에는 옆으로 글을 이어나가는 것보다는 밑으로 추가한다.)

# %%
# 2.1 import 예시

# 좋은 예
import os
import pandas as pd
import sklearn

# 안좋은 예시

import os, sys, pandas
from pandas import * # wildcard 사용은 소스의 모호함을 증가시켜 오류를 발생시킬수도 있음

# %%
#01-1. 본인 이름 출력 하기 - Input 문자형(기본)

print(f'본인 이름을 입력 하세요')
my_name = input()
print(f"제 이름은 {my_name} 입니다.")
# Out:
# 본인 이름을 입력 하세요
# ㅇ
# 제 이름은 ㅇ 입니다.

# %%
sum_1 = int(input('첫번째 숫자'))
sum_2 = int(input('두번째 숫자'))
print(sum_1 + sum_2)
# Out:
# 첫번째 숫자5
# 두번째 숫자7
# 12

# %%
# 숫자를 문자열로 바꾸기

ex1 = 52
ex1_str = str(52)

print(f"ex1은 {ex1}입니다.")
print(f"ex1은 {ex1_str}입니다.")

print(type(ex1))
print(type(ex1_str))
# Out:
# ex1은 52입니다.
# ex1은 52입니다.
# <class 'int'>
# <class 'str'>

# %%
# 문자를 숫자로 바꾸기

ex2_str_int = int(ex1_str)

print(f"ex1_str은 {ex1_str}입니다.")
print(f"ex2_str_int은 {ex2_str_int}입니다.")

print(type(ex1_str))
print(type(ex2_str_int))
# Out:
# ex1_str은 52입니다.
# ex2_str_int은 52입니다.
# <class 'str'>
# <class 'int'>

# %%
a = "10 20 30 40 50".split(" ")
a
# Out:
# ['10', '20', '30', '40', '50']

# %%
# 문자열과 In 연산자

print("멋쟁이" in "멋쟁이 사자 처럼")
# Out:
# True

# %%
ex3 = "멋쟁이 사자처럼"
print(ex3.find("사자"))
# Out:
# 4

# %%
# 공백 제거
# txt, csv -> python "멋쟁이 사자처럼" -> "  멋쟁이 사자처럼"

ex4 = "  안녕하세요 멋쟁이 사자처럼 입니다."
print(ex4)
print(ex4.strip())
# Out:
#   안녕하세요 멋쟁이 사자처럼 입니다.
# 안녕하세요 멋쟁이 사자처럼 입니다.

# %% [markdown]
# # Random 함수의 활용
#
# 데이터 분석시에 무작위 테스트를 하거나 샘플을 뽑고 싶을때 사용 -> 굉장히 많이 사용

# %%
import random

# %%
random.random()
# Out:
# 0.7711584652185441

# %%
#실수 숫자
random.uniform(1,10)
# Out:
# 2.092074050358165

# %%
#정수 숫자
random.randint(1,10)
# Out:
# 3

# %%
#짝수/홀수
#randrange

random.randrange(0,101,2) # 짝수
random.randrange(1,101,2) # 홀수
# Out:
# 57

# %%
#랜덤하게 하나의 원소 선택
random.choice('hello')
# Out:
# 'l'

# %%
random.choice(['바나나','사과','오렌지'])
# Out:
# '사과'

# %%
random.sample([1,2,3,4,5],3)
# Out:
# [3, 5, 4]

# %%
random.sample(range(1,5),3)
# Out:
# [1, 4, 2]

# %%
#로또번호
random.sample(range(1,46),6)
# Out:
# [42, 10, 29, 39, 44, 19]

# %%
#shuffle함수

items = [1,2,3,4,5]
random.shuffle(items)
print(items)
# Out:
# [2, 5, 3, 1, 4]

# %%
# 실습 1. 로또번호 1~45번까지 6개 번호 추출해보기
# seed 고정

random.seed(502)
lotto = random.sample(range(1,46), 6)
print(f"로또번호는 {lotto}입니다")
# Out:
# 로또번호는 [33, 24, 11, 41, 23, 43]입니다

# %%
#.실습 2. 보드게임 주사위 2개 던지기 -> 난수 추첨
# 랜덤으로 1부터 6까지 숫자를 생성해서

# die1 die2 합을 출력하는 프로그램을 만드세요

die1 = random.randint(1,6)
die2 = random.randint(1,6)

result = die1 + die2
result
# Out:
# 9

# %%
#. 실습 3. 오늘의 점심 메뉴 
# -> 리스트로 가져와서 오늘 먹을 점심메뉴를 선택하는 
# 랜덤 프로그램을 만들어보세요


menu = ['고기','햄버거','치즈']
lunch = random.choice(menu)
lunch
# Out:
# '고기'

# %%
# 실습 4. 가위바위보 게임 만들기
# 컴퓨터 낸거는 랜덤으로 바뀌어야 함
computer = ['가위','바위','보']
# 내가 낸거는 input()
computer_select = random.choice(computer)
# 승패는 상관없이 서로 무엇을 냈는지 출력
user = input('가위 바위 보 중 하나를 내세요')
# 컴퓨터는 {}
print(f'컴퓨터는 {computer_select}를 냈습니다.')
# 나는 {}
print(f'나는 {user}를 냈습니다.')
# Out:
# 가위 바위 보 중 하나를 내세요qkdn
# 컴퓨터는 가위를 냈습니다.
# 나는 qkdn를 냈습니다.

# %% [markdown]
# # 시간 함수

# %%
import time

# %%
time.time()
# Out:
# 1682928261.4764082

# %%
time.ctime()
# Out:
# 'Mon May  1 08:04:29 2023'

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2023, tm_mon=5, tm_mday=1, tm_hour=8, tm_min=4, tm_sec=40, tm_wday=0, tm_yday=121, tm_isdst=0)

# %%
import datetime

# %%
datetime.datetime
# Out:
# datetime.datetime

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2023, 5, 1, 8, 5, 16, 205029)

# %%
now.date()
# Out:
# datetime.date(2023, 5, 1)

# %%
now.time()
# Out:
# datetime.time(8, 5, 16, 205029)

# %%
now.year
# Out:
# 2023

# %%
now.month
# Out:
# 5

# %%
now.day
#시 hour, 분 minute 초 second 요일 weekend
# Out:
# 1

# %% [markdown]
# # 시간 쓰는 법법

# %%
import pytz

datetime.now(pytz.timezone('UTC'))

datetime.now(pytz.timezone('Asia/Seoul'))
# Out:
# datetime.datetime(2023, 5, 1, 17, 6, 32, 333238, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %%
from datetime import timedelta, timezone
datetime.now(timezone(timedelta(hours=9)))
# Out:
# datetime.datetime(2023, 5, 1, 17, 6, 39, 49520, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400)))

# %%
from datetime import datetime
from datetime import timedelta, timezone


now = datetime.now(timezone(timedelta(hours=9)))

print("현재 : ", now)
print("현재 날짜 : ", now.date())
print("현재 시간 : ", now.time())
print("timestamp : ", now.timestamp())
print("년 : ", now.year)
print("월 : ", now.month)
print("일 : ", now.day)
print("시 : ", now.hour)
print("분 : ", now.minute)
print("초 : ", now.second)
print("마이크로초 : ", now.microsecond)
print("요일 : ", now.weekday())
print("문자열 변환 : ", now.strftime('%Y-%m-%d %H:%M:%S'))

# Output
# 현재 :  2021-12-22 15:46:26.695840
# 현재 날짜 :  2021-12-22
# 현재 시간 :  15:46:26.695840
# timestamp :  1640155586.69584
# 년 :  2021
# 월 :  12
# 일 :  22
# 시 :  15
# 분 :  46
# 초 :  26
# 마이크로초 :  695840
# 요일 :  2
# 문자열 변환 :  2021-12-22 15:46:26
# Out:
# 현재 :  2023-05-01 17:06:52.887280+09:00
# 현재 날짜 :  2023-05-01
# 현재 시간 :  17:06:52.887280
# timestamp :  1682928412.88728
# 년 :  2023
# 월 :  5
# 일 :  1
# 시 :  17
# 분 :  6
# 초 :  52
# 마이크로초 :  887280
# 요일 :  0
# 문자열 변환 :  2023-05-01 17:06:52

# %% [markdown]
# # 파이썬 멈추기기

# %%
import time #sleep 함수 사용용

# %%
# 1. 초 단위 테스트
print('-' * 30)
now = datetime.now(timezone(timedelta(hours=9)))
print(now.strftime('%H:%M:%S')) # 현재 시간 출력

time.sleep(5) # 5 초 딜레이

now = datetime.now(timezone(timedelta(hours=9)))
print(now.strftime('%H:%M:%S'))

time.sleep(10) # 10 초 딜레이

print(datetime.now().strftime('%H:%M:%S'))
# Out:
# ------------------------------
# 17:07:41
# 17:07:46
# 08:07:56

# %% [markdown]
# # 파이썬 프로그램 시간 측정정

# %%
from time import process_time
start = time.time() # 측정 시작
print("★ 구구단을 출력합니다.\n")
for x in range(2, 10):
    print("------- [" + str(x) + "단] -------")
    for y in range(1, 10):
        print(x, "X", y, "=", x*y)
print("---------------------")
end = time.time() 
print('프로그램을 수행하는데', end - start, '초가 걸렸습니다.')
# Out:
# ★ 구구단을 출력합니다.
#
# ------- [2단] -------
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# ------- [3단] -------
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# ------- [4단] -------
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# ------- [5단] -------
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# ------- [6단] -------
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# ------- [7단] -------
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# ------- [8단] -------
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# ------- [9단] -------
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81
# ---------------------
# 프로그램을 수행하는데 0.10852813720703125 초가 걸렸습니다.

# %%
start = process_time()
print("★ 구구단을 출력합니다.\n")
for x in range(2, 10):
    print("------- [" + str(x) + "단] -------")
    for y in range(1, 10):
        print(x, "X", y, "=", x*y)
print("---------------------")
end = process_time()
print('프로그램을 수행하는데', end - start, '초가 걸렸습니다.')
# Out:
# ★ 구구단을 출력합니다.
#
# ------- [2단] -------
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# ------- [3단] -------
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# ------- [4단] -------
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# ------- [5단] -------
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# ------- [6단] -------
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# ------- [7단] -------
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# ------- [8단] -------
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# ------- [9단] -------
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81
# ---------------------
# 프로그램을 수행하는데 0.13894070699999972 초가 걸렸습니다.

# %%
# Out:
# 첫번째 주사위 값 :[1]
# 두번째 주사위 값 :[6]
# 두 주사위 합의 값 : [1, 6]

# %%
result
# Out:
# [4, 6]
